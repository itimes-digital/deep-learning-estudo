# %% [markdown]
# <a href="https://colab.research.google.com/github/itimes-digital/deep-learning-estudo/blob/main/classificacao_binaria_simples_breast_cancer_grid_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
previsores = pd.read_csv("https://raw.githubusercontent.com/itimes-digital/deep-learning-estudo/main/dataset/entradas_breast.csv", sep=",")
previsores.head()
# Out:
#     radius_mean   texture_mean  ...   symmetry_worst   fractal_dimension_worst
# 0         17.99          10.38  ...           0.4601                   0.11890
# 1         20.57          17.77  ...         275.0000                   0.08902
# 2         19.69          21.25  ...           0.3613                   0.08758
# 3         11.42          20.38  ...           0.6638                 173.00000
# 4         20.29          14.34  ...           0.2364                   0.07678
#
# [5 rows x 30 columns]

# %%
previsores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0    radius_mean              569 non-null    float64
#  1    texture_mean             569 non-null    float64
#  2    perimeter_mean           569 non-null    float64
#  3    area_mean                569 non-null    float64
#  4    smoothness_mean          569 non-null    float64
#  5    compactness_mean         569 non-null    float64
#  6    concavity_mean           569 non-null    float64
#  7   concave_points_mean       569 non-null    float64
#  8    symmetry_mean            569 non-null    float64
#  9    fractal_dimension_mean   569 non-null    float64
#  10   radius_se                569 non-null    float64
#  11   texture_se               569 non-null    float64
#  12   perimeter_se             569 non-null    float64
#  13   area_se                  569 non-null    float64
#  14   smoothness_se            569 non-null    float64
#  15   compactness_se           569 non-null    float64
#  16   concavity_se             569 non-null    float64
#  17   concave_points_se        569 non-null    float64
#  18   symmetry_se              569 non-null    float64
#  19   fractal_dimension_se     569 non-null    float64
#  20   radius_worst             569 non-null    float64
#  21   texture_worst            569 non-null    float64
#  22   perimeter_worst          569 non-null    float64
#  23   area_worst               569 non-null    float64
#  24   smoothness_worst         569 non-null    float64
#  25   compactness_worst        569 non-null    float64
#  26   concavity_worst          569 non-null    float64
#  27   concave_points_worst     569 non-null    float64
#  28   symmetry_worst           569 non-null    float64
#  29   fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30)
# memory usage: 133.5 KB

# %%
classe = pd.read_csv("https://raw.githubusercontent.com/itimes-digital/deep-learning-estudo/main/dataset/saidas_breast.csv")
classe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       569 non-null    int64
# dtypes: int64(1)
# memory usage: 4.6 KB

# %%
classe.head()
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
import keras

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Definição do números de neurônios por camada:
#
# (numero de entrada + numero de saídas esperada) / 2 = número de units na camada.

# %%
# Medida base para definir a quantidade de neurônios na camada.
# Como a classificação é binária, a resposta será 0 ou 1, portanto, uma saída.
quantSaidaEsperada = 1
neurons = (previsores.columns.size + quantSaidaEsperada) / 2
neurons = np.round(neurons)
neurons
# Out:
# 16.0

# %%
def criarRede(optimizer, 
              lossFunction, 
              kernel_initializer,
              activation,
              neurons):
  # input_dim define a quantidade de neurônios para a camada de entrada.
  classificador = Sequential() # Estrutura básica para colocar as camadas sequencialmente
  classificador.add(Dense(units=neurons, # define a quantidade de neurônios a camada oculta 
                        activation=activation, 
                        kernel_initializer=kernel_initializer, 
                        input_dim=30));# Quantidade de atributos de entrada

  # Dropout para minimizar o overfitting, zerando aleatoriamente os dados da camada
  classificador.add(Dropout(0.2)); # 20% dos dados

  # Camada intermediária ou oculta
  classificador.add(Dense(units=neurons, # define a quantidade de neurônios a camada oculta
                        activation=activation, 
                        kernel_initializer=kernel_initializer));

  # Dropout para minimizar o overfitting, zerando aleatoriamente os dados da camada
  classificador.add(Dropout(0.2)); # 20% dos dados

  # Definindo a camada de saída
  # Como é um classificador binário para 0 ou 1
  # A quantidade de neurônio é 1
  classificador.add(Dense(units=1, activation="sigmoid"))

  # para classificação binária deve usar binary_crossentropy
  # para classificação com mais de duas classes deve usar categorical_crossentropy
  classificador.compile(optimizer= optimizer, 
                      loss=lossFunction,
                      metrics=['binary_accuracy']);
                  
  return classificador;

# %%
classificador = KerasClassifier(build_fn = criarRede);

parametros = {'batch_size': [50, 100],
              'epochs': [5, 10],
              'optimizer': ['adam', 'sgd'],
              'lossFunction': ['binary_crossentropy', 'hinge'],
              'kernel_initializer': ['random_uniform', 'normal'],
              'activation': ['relu', 'tanh'],
              'neurons': [16, 8]};

# %%
grid_search = GridSearchCV(estimator = classificador,
                           param_grid = parametros,
                           scoring = 'accuracy',
                           cv = 5)

grid_search = grid_search.fit(previsores, classe)
# Out:
# Streaming output truncated to the last 5000 lines.
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6555 - binary_accuracy: 0.6220
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0831ff9ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6865 - binary_accuracy: 0.5692
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6650 - binary_accuracy: 0.6352
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6548 - binary_accuracy: 0.6418
# Epoch 4/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6446 - binary_accuracy: 0.6022
# Epoch 5/5
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6304 - binary_accuracy: 0.6198
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0835bdef28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6876 - binary_accuracy: 0.5373
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6783 - binary_accuracy: 0.5943
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6688 - binary_accuracy: 0.5877
# Epoch 4/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6617 - binary_accuracy: 0.5965
# Epoch 5/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6627 - binary_accuracy: 0.6031
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f083818f488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6889 - binary_accuracy: 0.5560
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6699 - binary_accuracy: 0.6571
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6647 - binary_accuracy: 0.6747
# Epoch 4/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6516 - binary_accuracy: 0.6747
# Epoch 5/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6477 - binary_accuracy: 0.6769
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0830d8fb70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6794 - binary_accuracy: 0.6000
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6741 - binary_accuracy: 0.6044
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6640 - binary_accuracy: 0.6176
# Epoch 4/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6573 - binary_accuracy: 0.6220
# Epoch 5/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6609 - binary_accuracy: 0.6308
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f082f10ca60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6944 - binary_accuracy: 0.5033
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6851 - binary_accuracy: 0.5648
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6754 - binary_accuracy: 0.5912
# Epoch 4/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6711 - binary_accuracy: 0.6220
# Epoch 5/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6637 - binary_accuracy: 0.6132
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f082c9a6620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6902 - binary_accuracy: 0.5516
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6830 - binary_accuracy: 0.5670
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6829 - binary_accuracy: 0.5868
# Epoch 4/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6803 - binary_accuracy: 0.5868
# Epoch 5/5
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6795 - binary_accuracy: 0.5934
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0835d4bb70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6899 - binary_accuracy: 0.5548
# Epoch 2/5
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6855 - binary_accuracy: 0.5702
# Epoch 3/5
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6835 - binary_accuracy: 0.5746
# Epoch 4/5
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6820 - binary_accuracy: 0.5877
# Epoch 5/5
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6842 - binary_accuracy: 0.5877
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f082ebee488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7834 - binary_accuracy: 0.6593
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7447 - binary_accuracy: 0.6725
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.
5
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6780 - binary_accuracy: 0.5714
# Epoch 5/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6680 - binary_accuracy: 0.6022
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f083228c488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6954 - binary_accuracy: 0.5297
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6887 - binary_accuracy: 0.5934
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6863 - binary_accuracy: 0.5846
# Epoch 4/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6762 - binary_accuracy: 0.5824
# Epoch 5/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6829 - binary_accuracy: 0.5824
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0834ac78c8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6983 - binary_accuracy: 0.5175
# Epoch 2/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6863 - binary_accuracy: 0.5680
# Epoch 3/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6906 - binary_accuracy: 0.5329
# Epoch 4/5
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6872 - binary_accuracy: 0.5351
# Epoch 5/5
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6871 - binary_accuracy: 0.5636
# ...
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8817 - binary_accuracy: 0.4418
# Epoch 2/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8770 - binary_accuracy: 0.5165
# Epoch 3/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8736 - binary_accuracy: 0.5495
# Epoch 4/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8697 - binary_accuracy: 0.5912
# Epoch 5/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8652 - binary_accuracy: 0.6066
# Epoch 6/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8604 - binary_accuracy: 0.6154
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8571 - binary_accuracy: 0.6132
# Epoch 8/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8541 - binary_accuracy: 0.6176
# Epoch 9/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8470 - binary_accuracy: 0.6110
# Epoch 10/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8416 - binary_accuracy: 0.6264
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f082790b048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9009 - binary_accuracy: 0.5165
# Epoch 2/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8980 - binary_accuracy: 0.5758
# Epoch 3/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8951 - binary_accuracy: 0.5714
# Epoch 4/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8901 - binary_accuracy: 0.5868
# Epoch 5/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8882 - binary_accuracy: 0.5802
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8814 - binary_accuracy: 0.5868
# Epoch 7/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8807 - binary_accuracy: 0.5912
# Epoch 8/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8760 - binary_accuracy: 0.5868
# Epoch 9/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8724 - binary_accuracy: 0.5868
# Epoch 10/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8661 - binary_accuracy: 0.5912
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f082f051158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9006 - binary_accuracy: 0.5504
# Epoch 2/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8893 - binary_accuracy: 0.5811
# Epoch 3/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8881 - binary_accuracy: 0.5768
# Epoch 4/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8826 - binary_accuracy: 0.5921
# Epoch 5/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8733 - binary_accuracy: 0.5943
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8676 - binary_accuracy: 0.5921
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8654 - binary_accuracy: 0.5921
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8603 - binary_accuracy: 0.5921
# Epoch 9/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8640 - binary_accuracy: 0.5899
# Epoch 10/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8527 - binary_accuracy: 0.5921
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f082d806048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8137 - binary_accuracy: 0.5231
# Epoch 2/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8107 - binary_accuracy: 0.5692
# Epoch 3/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8075 - binary_accuracy: 0.6330
# Epoch 4/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8035 - binary_accuracy: 0.6220
# Epoch 5/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7991 - binary_accuracy: 0.6242
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7944 - binary_accuracy: 0.6725
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7958 - binary_accuracy: 0.6615
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7919 - binary_accuracy: 0.6549
# Epoch 9/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7839 - binary_accuracy: 0.6791
# Epoch 10/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7844 - binary_accuracy: 0.6703
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0825092ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8501 - binary_accuracy: 0.5824
# Epoch 2/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8457 - binary_accuracy: 0.5978
# Epoch 3/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8426 - binary_accuracy: 0.6154
# Epoch 4/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8419 - binary_accuracy: 0.6220
# Epoch 5/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8397 - binary_accuracy: 0.6242
# Epoch 6/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8388 - binary_accuracy: 0.6176
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8321 - binary_accuracy: 0.6242
# Epoch 8/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8332 - binary_accuracy: 0.6176
# Epoch 9/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8320 - binary_accuracy: 0.6242
# Epoch 10/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8322 - binary_accuracy: 0.6132
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0828037268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8893 - binary_accuracy: 0.4110
# Epoch 2/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8779 - binary_accuracy: 0.4703
# Epoch 3/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8797 - binary_accuracy: 0.4835
# Epoch 4/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8740 - binary_accuracy: 0.5253
# Epoch 5/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8761 - binary_accuracy: 0.5231
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8704 - binary_accuracy: 0.5714
# Epoch 7/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8667 - binary_accuracy: 0.5912
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8618 - binary_accuracy: 0.6066
# Epoch 9/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8588 - binary_accuracy: 0.6220
# Epoch 10/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8592 - binary_accuracy: 0.6110
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0827e5f950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8973 - binary_accuracy: 0.5495
# Epoch 2/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8977 - binary_accuracy: 0.5385
# Epoch 3/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9001 - binary_accuracy: 0.5209
# Epoch 4/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8958 - binary_accuracy: 0.5253
# Epoch 5/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8962 - binary_accuracy: 0.5626
# Epoch 6/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8944 - binary_accuracy: 0.5209
# Epoch 7/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8905 - binary_accuracy: 0.5758
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8979 - binary_accuracy: 0.5143
# Epoch 9/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8946 - binary_accuracy: 0.5626
# Epoch 10/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8947 - binary_accuracy: 0.5363
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08217d66a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9014 - binary_accuracy: 0.5219
# Epoch 2/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8938 - binary_accuracy: 0.5789
# Epoch 3/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8913 - binary_accuracy: 0.5987
# Epoch 4/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8915 - binary_accuracy: 0.5943
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8879 - binary_accuracy: 0.5855
# Epoch 6/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8878 - binary_accuracy: 0.5855
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8854 - binary_accuracy: 0.5548
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8865 - binary_accuracy: 0.5724
# Epoch 9/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.8871 - binary_accuracy: 0.5789
# Epoch 10/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8897 - binary_accuracy: 0.5658
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f08281536a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/10
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9701 - binary_accuracy: 0.5237
# Epoch 2/10
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3062 - binary_accuracy: 0.5817
# Epoch 3/10
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7749 - binary_accuracy: 0.6678
# Epoch 4/10
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6263 - binary_accuracy: 0.7030
# Epoch 5/10
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5642 - binary_accuracy: 0.7083
# Epoch 6/10
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5034 - binary_accuracy: 0.7540
# Epoch 7/10
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4966 - binary_accuracy: 0.7575
# Epoch 8/10
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4876 - binary_accuracy: 0.7417
# Epoch 9/10
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4886 - binary_accuracy: 0.7540
# Epoch 10/10
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4341 - binary_accuracy: 0.7803

# %%
melhores_params = grid_search.best_params_
melhores_precisao = grid_search.best_score_

# %%
melhores_params
# Out:
# {'activation': 'relu',
#  'batch_size': 50,
#  'epochs': 10,
#  'kernel_initializer': 'random_uniform',
#  'lossFunction': 'binary_crossentropy',
#  'neurons': 16,
#  'optimizer': 'adam'}

# %%
melhores_precisao
# Out:
# 0.743145474305232
